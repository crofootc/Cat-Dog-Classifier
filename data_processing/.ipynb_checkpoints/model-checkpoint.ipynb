# %%
from matplotlib import pyplot
from matplotlib.image import imread
import os

# %%
c_folder = r'C:\\Users\\cdcro\\Documents\\Projects\\ml1\\data_processing\\cats\\'
d_folder = r'C:\\Users\\cdcro\\Documents\\Projects\\ml1\\data_processing\\dogs\\'

# %%
os.path.exists(d_folder)
# Out:
# True

# %%
with open('dog_url.txt', 'r') as f:
    dogs = f.readlines()

with open('cat_url.txt', 'r') as f:
    cats = f.readlines()

print('dogs: ', len(dogs))
print('cats: ', len(cats))
# Out:
# dogs:  38088
# cats:  246542

# %%
print(dogs[0].rsplit('\n')[0])
# Out:
# https://i.redd.it/llxof0txk6821.jpg

# %%
for i in range(9):
    pyplot.subplot(330 + 1 + i)
    filename = d_folder + "dog" + str(i) + ".jpg"
    image = imread(filename)
    pyplot.imshow(image)
pyplot.show()

# %%
for i in range(9):
    pyplot.subplot(330 + 1 + i)
    filename = c_folder + "cat" + str(i) + ".jpg"
    image = imread(filename)
    pyplot.imshow(image)
pyplot.show()
